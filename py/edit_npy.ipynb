# %%
import numpy as np
import AR
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams["axes.labelpad"] = -1.7

# %%
a = np.abs(np.load("/Users/hibiki/Documents/cpp/beta0.5_nu1e-05_10000period.npy"))
np.max(a, axis=1)
# Out:
# array([6.71346879e-01, 6.41798493e-01, 5.58229424e-01, 3.73568202e-01,
#        4.05778553e-01, 3.69391086e-01, 3.11250991e-01, 2.56594141e-01,
#        2.15351203e-01, 1.81350920e-01, 1.75857695e-01, 1.33130565e-01,
#        1.23656096e-01, 1.41755798e-01, 6.72223654e-02, 9.99999000e+03])

# %%
#sin t を生成
start = 100
sec = 1000
dt = 0.01
sin = np.sin(np.arange(start, start+sec, dt))
sin += np.sin(np.sqrt(2)*np.arange(start, start+sec, dt))
plt.plot(sin)
np.save(f"../sin/sin{sec}sec_dt={dt}_merged.npy", sin)

# %%
plt.plot(np.load("../lorenz-upos/dat-upo-T12.692183z-periodic.npy"))

# %%
fname = "../lorenz/dat-upo-T12.692183z-periodic.npy"
a =  np.load(fname)
a = np.concatenate((a, a), axis=0)

np.save(fname+".npy", a)

# %%
#フーリエ変換で打ち切りがどれだけ影響するか
plt.figure(figsize=(10, 4))
plt.plot(np.loadtxt("../lorenz-upos/dat-upo-T11.256767143036276z-periodic")[::10, 1], label="original")
plt.plot(np.loadtxt("../lorenz-upos/dat-upo-T11.256767143036276z-periodic-fourier-sum0-256")[::10, 1], label="0-256")
plt.plot(np.loadtxt("../lorenz-upos/dat-upo-T11.256767143036276z-periodic-fourier-sum0-40")[::10, 1], label="0-40")
plt.plot(np.loadtxt("../lorenz-upos/dat-upo-T11.256767143036276z-periodic-fourier-sum0-30")[::10, 1], label="0-30")
plt.xlabel("t")
plt.ylabel("z")
plt.legend()

# %%
lo = np.load("../logistic/logistic_3.9_1000000_10000dumped.npy")

plt.figure(figsize=(7, 7))
plt.scatter(lo[:-1], lo[1:], s=1)

# %%
cyc = np.load("../lorenz/3137.05sec1000dump_dt=0.01sigma10rho28beta2.66667epsilon0.001.npy")[:, :10]
cyc2 = np.load("../lorenz_orbit/8676.53sec1000dump_dt=0.01sigma10rho28beta2.66667epsilon0.01.npy")[:, -10:]
#cycの3次元をプロット
fig = plt.figure(figsize=(8, 8  ))
ax = fig.add_subplot(111, projection='3d')
ax.plot(cyc[0, ], cyc[1, ], cyc[2, ])
ax.plot(cyc2[0, ], cyc2[1, ], cyc2[2, ])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR model/py/edit_npy.ipynb セル 7 line 6
#       <a href='vscode-notebook-cell:/Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR%20model/py/edit_npy.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> fig = plt.figure(figsize=(8, 8  ))
#       <a href='vscode-notebook-cell:/Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR%20model/py/edit_npy.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> ax = fig.add_subplot(111, projection='3d')
# ----> <a href='vscode-notebook-cell:/Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR%20model/py/edit_npy.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> ax.plot(cyc, cyc[1, ], cyc)
#       <a href='vscode-notebook-cell:/Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR%20model/py/edit_npy.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> ax.plot(cyc2, cyc2[1, ], cyc2)
#       <a href='vscode-notebook-cell:/Users/hibiki/Library/CloudStorage/Dropbox/RA2022/kato/AR%20model/py/edit_npy.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> ax.set_xlabel("x")
#
# File ~/miniforge3/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:1617, in Axes3D.plot(self, xs, ys, zdir, *args, **kwargs)
#    1614 # Match length
#    1615 zs = np.broadcast_to(zs, np.shape(xs))
# -> 1617 lines = super().plot(xs, ys, *args, **kwargs)
#    1618 for line in lines:
#    1619     art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#
# File ~/miniforge3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/miniforge3/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniforge3/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (313705,) and (1,)
